# %%
import numpy as np

# %%
mu = [0.3, 0.7]

mu = np.array(mu)

mu
# Out:
# array([0.3, 0.7])

# %%
p = [
    [0.8, 0.2],
    [0.6, 0.4]
    ]

p = np.matrix(p)

# %%
p_2 = p.dot(p)

p_2
# Out:
# matrix([[0.76, 0.24],
#         [0.72, 0.28]])

# %%
mu.dot(p)
# Out:
# matrix([[0.66, 0.34]])

# %%
mu.dot(p.dot(p))
# Out:
# matrix([[0.732, 0.268]])

# %%
p_3 = p_2.dot(p)

p_3
# Out:
# matrix([[0.752, 0.248],
#         [0.744, 0.256]])

# %%
mu.dot(p_3)
# Out:
# matrix([[0.7464, 0.2536]])

# %%
mu.dot(p_2)
# Out:
# matrix([[0.732, 0.268]])

# %%
mu.dot(p_3)
# Out:
# matrix([[0.7464, 0.2536]])
